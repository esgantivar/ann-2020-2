# %%
import h5py
import tensorflow as tf
import os
import shutil

# %%
from fuel.datasets import H5PYDataset
from tqdm import tqdm
from keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array
from keras.applications.mobilenet_v2 import MobileNetV2, preprocess_input

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img

# %%
from build_dataset import build_subset, generate_h5

# %%
import numpy as np
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras.models import Sequential,Model
from tensorflow.keras.layers import Activation, Dense, Flatten, BatchNormalization, Conv2D, MaxPool2D, Dropout
from tensorflow.keras.optimizers import Adam

# %%
img = load_img('storage/BreaKHis_v1/histology_slides/breast/malignant/SOB/papillary_carcinoma/SOB_M_PC_14-15704/400X/SOB_M_PC-14-15704-400-006.png')  # this is a PIL image
x = img_to_array(img)  # this is a Numpy array with shape (3, 150, 150)
plt.imshow(img)

# %%
img = load_img('storage/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-29960CD/400X/SOB_B_A-14-29960CD-400-007.png')  # this is a PIL image
x = img_to_array(img)  # this is a Numpy array with shape (3, 150, 150)
plt.imshow(img)

# %%
# %run -i 'generate_lists.py'

# %%
generate_h5(build_subset(40),
            name='breakhis_40PX_128', 
            path='storage/breakhis/40PX', 
            target_size=(128, 128), 
            img_size=[128, 128])
# Out:
# ...
# 100%|██████████| 1995/1995 [00:32<00:00, 60.69it/s]

# %%
generate_h5(build_subset(100),
            name='breakhis_100PX_128', 
            path='storage/breakhis/100PX', 
            target_size=(128, 128), 
            img_size=[128, 128])
# Out:
# ...
# 100%|██████████| 2081/2081 [00:34<00:00, 60.20it/s]

# %%
generate_h5(build_subset(200),
            name='breakhis_200PX_128', 
            path='storage/breakhis/200PX', 
            target_size=(128, 128), 
            img_size=[128, 128])
# Out:
# ...
# 100%|██████████| 2013/2013 [00:32<00:00, 61.22it/s]

# %%
generate_h5(build_subset(400),
            name='breakhis_400PX_128', 
            path='storage/breakhis/400PX', 
            target_size=(128, 128), 
            img_size=[128, 128])
# Out:
# ...
# 100%|██████████| 1820/1820 [00:28<00:00, 64.58it/s]

# %%
# !rm -rf storage/breakhis
